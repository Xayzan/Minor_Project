# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Book1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 21 columns):
#  #   Column                                                                                                                                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                      --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                   290 non-null    object
# ...

# %%
df.head()
# Out:
#                         Timestamp  \
# 0  2022/12/07 9:21:08 PM GMT+5:30
# 1  2022/12/07 9:21:24 PM GMT+5:30
# 2  2022/12/07 9:23:47 PM GMT+5:30
# 3  2022/12/07 9:27:40 PM GMT+5:30
# 4  2022/12/07 9:36:51 PM GMT+5:30
#
#              Which line(s) of DMRC Network you use ?  \
# 0                     Red Line;Violet Line;Pink Line
# 1                                          Blue Line
# 2  Yellow Line;Blue Line;Pink Line;Magenta Line;A...
# 3                                 Red Line;Pink Line
# 4                                        Yellow Line
#
#   Which line of DMRC Network you use the most ?  \
# 0                                   Violet Line
# 1                                     Blue Line
# 2                                  Magenta Line
# 3                                     Pink Line
# 4                                   Yellow Line
#
#    How important are platform screen doors for safety?  \
# 0                                                  5
# ...

# %%
df.set_index('Timestamp')
# Out:
#                                           Which line(s) of DMRC Network you use ?  \
# Timestamp
# 2022/12/07 9:21:08 PM GMT+5:30                     Red Line;Violet Line;Pink Line
# 2022/12/07 9:21:24 PM GMT+5:30                                          Blue Line
# 2022/12/07 9:23:47 PM GMT+5:30  Yellow Line;Blue Line;Pink Line;Magenta Line;A...
# 2022/12/07 9:27:40 PM GMT+5:30                                 Red Line;Pink Line
# 2022/12/07 9:36:51 PM GMT+5:30                                        Yellow Line
# ...                                                                           ...
# 2023/01/08 6:01:37 PM GMT+5:30                              Blue Line;Violet Line
# 2023/01/08 6:01:37 PM GMT+5:30                              Blue Line;Violet Line
# 2023/01/08 6:01:37 PM GMT+5:30                              Blue Line;Violet Line
# 2023/01/08 6:01:37 PM GMT+5:30                              Blue Line;Violet Line
# ...

# %%
df.corr()
# Out:
#                                                     How important are platform screen doors for safety?  \
# How important are platform screen doors for saf...                                           1.000000
# How comfortable are you in the overall closing ...                                           0.242506
# Do you find the emergency push to talk button n...                                           0.406942
# How important presence of CCTV surveillance ? (...                                           0.304969
# How useful do you find door indicator system ?(...                                           0.331526
# How comfortable are you with the gap between pl...                                           0.046074
# Are you satisfied with the seating capacity/arr...                                           0.444913
# Do you feel metro should have seats like on a bus?                                          -0.261046
# ...

# %%
df['Which line of DMRC Network you use the most ?'].value_counts()
# Out:
# Blue Line                                       63
# Pink Line                                       58
# Red Line                                        33
# Yellow Line                                     32
# Magenta Line                                    28
# Green Line                                      24
# Aqua Line (Noida - GrNoida Corridor of NMRC)    15
# Orange Line (Airport Express)                   15
# Violet Line                                     14
# Grey Line                                        8
# Name: Which line of DMRC Network you use the most ?, dtype: int64

# %%
sns.pairplot(df)

# %%
pink_line = df['Which line of DMRC Network you use the most ?'] == 'Pink Line'

# %%
df2 = df[pink_line]

# %%
df2.corr()
# Out:
#                                                     How important are platform screen doors for safety?  \
# How important are platform screen doors for saf...                                           1.000000
# How comfortable are you in the overall closing ...                                           0.160182
# Do you find the emergency push to talk button n...                                           0.618185
# How important presence of CCTV surveillance ? (...                                          -0.464093
# How useful do you find door indicator system ?(...                                          -0.153727
# How comfortable are you with the gap between pl...                                          -0.090300
# Are you satisfied with the seating capacity/arr...                                           0.146089
# Do you feel metro should have seats like on a bus?                                          -0.710235
# ...

# %%
magenta_line = df['Which line of DMRC Network you use the most ?'] == 'Magenta Line'

# %%
df3 = df[magenta_line]

# %%
new_line = pd.concat([df2,df3], ignore_index=True)

# %%
new_line
# Out:
#                          Timestamp  \
# 0   2022/12/07 9:27:40 PM GMT+5:30
# 1   2022/12/11 7:32:56 PM GMT+5:30
# 2   2023/01/03 1:56:43 PM GMT+5:30
# 3   2023/01/03 2:41:14 PM GMT+5:30
# 4   2023/01/05 9:36:48 PM GMT+5:30
# ..                             ...
# 81  2023/01/08 5:45:09 PM GMT+5:30
# 82  2023/01/08 5:45:09 PM GMT+5:30
# 83  2023/01/08 5:45:09 PM GMT+5:30
# 84  2023/01/08 5:45:09 PM GMT+5:30
# 85  2023/01/08 5:45:11 PM GMT+5:30
#
#               Which line(s) of DMRC Network you use ?  \
# 0                                  Red Line;Pink Line
# 1                                            Red Line
# 2                                  Red Line;Pink Line
# 3   Red Line;Blue Line;Pink Line;Aqua Line (Noida ...
# 4                      Red Line;Yellow Line;Pink Line
# ..                                                ...
# 81                    Red Line;Blue Line;Magenta Line
# 82                    Red Line;Blue Line;Magenta Line
# ...

# %%
red_line = df['Which line of DMRC Network you use the most ?'] == 'Red Line'

# %%
df4 = df[red_line]

# %%
df4.corr()
# Out:
#                                                     How important are platform screen doors for safety?  \
# How important are platform screen doors for saf...                                           1.000000
# How comfortable are you in the overall closing ...                                          -0.113391
# Do you find the emergency push to talk button n...                                           0.018380
# How important presence of CCTV surveillance ? (...                                           0.633624
# How useful do you find door indicator system ?(...                                           0.091526
# How comfortable are you with the gap between pl...                                           0.249117
# Are you satisfied with the seating capacity/arr...                                           0.498334
# Do you feel metro should have seats like on a bus?                                          -0.470132
# ...

# %%
blue_line = df['Which line of DMRC Network you use the most ?'] == 'Blue Line'

# %%
df5 = df[blue_line]

# %%
df5.corr()
# Out:
#                                                     How important are platform screen doors for safety?  \
# How important are platform screen doors for saf...                                           1.000000
# How comfortable are you in the overall closing ...                                          -0.191421
# Do you find the emergency push to talk button n...                                           0.410757
# How important presence of CCTV surveillance ? (...                                           0.658837
# How useful do you find door indicator system ?(...                                           0.242337
# How comfortable are you with the gap between pl...                                          -0.128119
# Are you satisfied with the seating capacity/arr...                                           0.688752
# Do you feel metro should have seats like on a bus?                                          -0.797441
# ...

# %%
old_line = pd.concat([df4, df5], ignore_index=True)

# %%
old_line
# Out:
#                          Timestamp  \
# 0   2022/12/08 7:29:32 AM GMT+5:30
# 1   2023/01/05 9:19:37 PM GMT+5:30
# 2   2023/01/08 3:11:07 PM GMT+5:30
# 3   2023/01/08 3:11:36 PM GMT+5:30
# 4   2023/01/08 3:18:21 PM GMT+5:30
# ..                             ...
# 91  2023/01/08 5:59:14 PM GMT+5:30
# 92  2023/01/08 5:59:14 PM GMT+5:30
# 93  2023/01/08 5:59:14 PM GMT+5:30
# 94  2023/01/08 5:59:14 PM GMT+5:30
# 95  2023/01/08 5:59:14 PM GMT+5:30
#
#               Which line(s) of DMRC Network you use ?  \
# 0                      Red Line;Yellow Line;Blue Line
# 1        Yellow Line;Blue Line;Pink Line;Magenta Line
# 2                                            Red Line
# 3                      Red Line;Yellow Line;Blue Line
# 4            Red Line;Yellow Line;Blue Line;Pink Line
# ..                                                ...
# 91  Yellow Line;Blue Line;Pink Line;Magenta Line;O...
# 92  Yellow Line;Blue Line;Pink Line;Magenta Line;O...
# ...

# %%
combined = pd.concat([old_line, new_line], ignore_index=True)

# %%
combined
# Out:
#                           Timestamp  \
# 0    2022/12/08 7:29:32 AM GMT+5:30
# 1    2023/01/05 9:19:37 PM GMT+5:30
# 2    2023/01/08 3:11:07 PM GMT+5:30
# 3    2023/01/08 3:11:36 PM GMT+5:30
# 4    2023/01/08 3:18:21 PM GMT+5:30
# ..                              ...
# 177  2023/01/08 5:45:09 PM GMT+5:30
# 178  2023/01/08 5:45:09 PM GMT+5:30
# 179  2023/01/08 5:45:09 PM GMT+5:30
# 180  2023/01/08 5:45:09 PM GMT+5:30
# 181  2023/01/08 5:45:11 PM GMT+5:30
#
#           Which line(s) of DMRC Network you use ?  \
# 0                  Red Line;Yellow Line;Blue Line
# 1    Yellow Line;Blue Line;Pink Line;Magenta Line
# 2                                        Red Line
# 3                  Red Line;Yellow Line;Blue Line
# 4        Red Line;Yellow Line;Blue Line;Pink Line
# ..                                            ...
# 177               Red Line;Blue Line;Magenta Line
# 178               Red Line;Blue Line;Magenta Line
# 179               Red Line;Blue Line;Magenta Line
# ...

# %%
combined.replace({'Which line of DMRC Network you use the most ?':{'Red Line':0, 'Blue Line':1, 'Pink Line':2, 'Magenta Line':3}}, inplace=True)

# %%
combined['Which line of DMRC Network you use the most ?'].value_counts()
# Out:
# 1    63
# 2    58
# 0    33
# 3    28
# Name: Which line of DMRC Network you use the most ?, dtype: int64

# %%
test = combined

# %%
test['Choice'] = np.where(test['How important are platform screen doors for safety?']>3,4,5)

# %%
test['Choice'].hist()
# Out:
# <AxesSubplot:>

# %%
test.columns
# Out:
# Index(['Timestamp', 'Which line(s) of DMRC Network you use ?',
#        'Which line of DMRC Network you use the most ?',
#        'How important are platform screen doors for safety?',
#        'How comfortable are you in the overall closing and opening of doors ?( getting stuck while they are closing for example.)',
#        'Do you find the emergency push to talk button needful?(for emergency services)',
#        'How important presence of CCTV surveillance ? (in terms of safety)',
#        'How useful do you find door indicator system ?(blinking light in newer metros indicating the door is opening and closing of door)',
#        'How comfortable are you with the gap between platform and train?',
#        'Are you satisfied with the seating capacity/arrangement?',
#        'Do you feel metro should have seats like on a bus?',
#        'Are you satisfied with the metro frequency?',
# ...

# %%
df.plot.scatter(x= 'How comfortable are you in the overall closing and opening of doors ?( getting stuck while they are closing for example.)', y='Are you satisfied with lighting?', c='Darkblue')
# Out:
# <AxesSubplot:xlabel='How comfortable are you in the overall closing and opening of doors ?( getting stuck while they are closing for example.)', ylabel='Are you satisfied with lighting?'>
